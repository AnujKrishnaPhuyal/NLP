# %% [markdown]
# <a href="https://colab.research.google.com/github/AnujKrishnaPhuyal/NLP/blob/main/Seq2seq_language_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchtext==0.6.0
# Out:
# Collecting torchtext==0.6.0
#   Using cached torchtext-0.6.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.31.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.23.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.16.0)
# Collecting sentencepiece (from torchtext==0.6.0)
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2023.11.17)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.6.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
# Installing collected packages: sentencepiece, torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.16.0
#     Uninstalling torchtext-0.16.0:
#       Successfully uninstalled torchtext-0.16.0
# Successfully installed sentencepiece-0.1.99 torchtext-0.6.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchtext
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator, TabularDataset
import spacy
import random
import numpy as np
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard
from utils import translate_sentence, bleu, save_checkpoint, load_checkpoint
from torchtext.data import Dataset
from torchtext.data.metrics import bleu_score

# %%
# !python -m spacy download de_core_news_sm
# !python -m spacy download en_core_web_sm
# Out:
# 2024-01-16 14:51:40.793596: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-16 14:51:40.793656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-16 14:51:40.797453: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-16 14:51:44.458153: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting de-core-news-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.6.0/de_core_news_sm-3.6.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 87.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from de-core-news-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->de-core-news-sm==3.6.0) (2.1.3)
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# 2024-01-16 14:52:01.467622: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-16 14:52:01.467686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-16 14:52:01.468840: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-16 14:52:02.551492: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spaCy models for German and English
spacy_ger = spacy.load("de_core_news_sm")
spacy_eng = spacy.load("en_core_web_sm")

# %%
# making tokenizer function

text = "I am a handsome guy"

def tok_english(text):
     return [tok.text for tok in spacy_eng.tokenizer(text)]

def tok_german(text):
     return [tok.text for tok in spacy_ger.tokenizer(text)]

# %%
# Read English and German files
with open('train/eng.en', 'r', encoding='utf-8') as f:
    train_english_sentences = [line.strip() for line in f.readlines()]

with open('train/ger.de', 'r', encoding='utf-8') as f:
    train_german_sentences = [line.strip() for line in f.readlines()]

# %%
train_data = list(zip(train_german_sentences,train_english_sentences))

# %%
train_data
# Out:
# [('zwei männer betrachten etwas im garten',
#   'two young guys with shaggy hair look at their hands while hanging out in the yard .'),
#  ('die männer arbeiten an der seilbahn .',
#   'several men in hard hats are operating a giant pulley system .'),
#  ('ein mädchen im rosa kleid klettert in eine stall',
#   'a child in a pink dress is climbing up a set of stairs in an entry way .'),
#  ('ein mann auf einer leiter putzt ein fenster',
#   'someone in a blue shirt and hat is standing on stair and leaning against a window .'),
#  ('ein mann am herd füllt den teller eines zweiten mannes .',
#   'two men , one in a gray shirt , one in a black shirt , standing near a stove .'),
#  ('ein maskenbildner bearbeitet das kostüm eines gitarristen .',
#   'two people in the photo are playing the guitar and the other is poking at him .'),
#  ('ein junger mann hält eine groeinße plüschfigur .',
#   'a man sits in a chair while holding a large stuffed animal of a lion .'),
#  ('eine frau im blauen shirt telefoniert beim rollschuhfahren .',
#   'a girl is on rollerskates talking on her cellphone standing in a parking lot .'),
#  ('2 faruen und ein mann laufen auf dem bordstein',
#   'an asian man wearing a black suit stands near a dark-haired woman and a brown-haired woman .'),
#  ('zwei männer mit nackten oberkörper die über ein geländer springen .',
#   'two men in germany jumping over a rail at the same time without shirts .'),
#  ('mädchen im balettunterrricht .',
#   'five ballet dancers caught mid jump in a dancing studio with sunlight coming through a window .'),
#  ('ein paar jugendliche springen eine treppe hinunter .',
#   'three young men and a young woman wearing sneakers are leaping in midair at the top of a flight of concrete stairs .'),
#  ('zwei hunde kämpfen',
#   'a black dog and a white dog with brown spots are staring at each other in the street .'),
#  ('ein bauarbeiter der auf einem traktor fährt .',
#   'a man with reflective safety clothes and ear protection drives a john deere tractor on a road .'),
#  ('einige menschen stehen neben einem bus .',
#   'some women are standing in front of a bus with buildings behind it .'),
#  ('eine junge frau , die mit einem sieb einen kuchen mit zucker bestreut .',
#   'a young woman with dark hair and wearing glasses is putting white powder on a cake using a sifter .'),
#  ('das mädchen sitzt vor einem gemalten regenbogen .',
#   'a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .'),
#  ('ein mann liegt auf einer bank und sein hund sitzt davor',
#   'a man sleeping on a bench outside with a white and black dog sitting next to him .'),
#  ('eine gruppe violinenspieler sitzt im kreis zusammen .',
#   'a group of adults , inside a home , sitting on chairs arranged in a circle , playing a type of musical instruments .'),
#  ('mehrere personen spielen instrumente',
#   'two women , both wearing glasses , are playing clarinets and an elderly woman is playing a stringed instrument .'),
#  ('ein man der steht im dunkel',
#   'a person in gray stands alone on a structure outdoors in the dark .'),
#  ('viele fußgänger auf einer straße , ein mann im vordergrund .',
#   'a man in a white t-shirt looks toward the camera surrounded by a crowd near a metro station .'),
#  ('ein tätowierer bei der arbeit .',
#   'a man with a goatee in a black shirt and white latex gloves is using a tattoo gun to place a tattoo on someone &apos;s back .'),
#  ('zwei kinder sitzen auf einer wippe .',
#   'two children , a girl and a boy are practicing their writing .'),
#  ('ein arbeiter macht etwas mit der strasse',
#   'a man in a blue hard hat and orange safety vest stands in an intersection while holding a flag .'),
#  ('eine person die ein bild malt .',
#   'a person with long gray hair has a beret with beige and white wearing a blue raincoat is painting a marketplace scenery surrounded by other artists and paintings .'),
#  ('ein mann mit reinigungswerkzeug tanzt auf einem platz .',
#   'a man stands on one foot while holding on to a waste basket .'),
#  ('ein kind beim spielen auf einem klettergerüst',
#   'a small child grips onto the red ropes at the playground .'),
#  ('ein mann mit einem schwan , der aus papier gefaltet wurde .',
#   'young man in jacket holding a toothpick with something on the end of it'),
#  ('ein sportler hält einen stab .',
#   'young blond man in a blue and yellow jacket smiling while standing in front of a net .'),
#  ('der mann steht vor den urinalen .',
#   'a man with a baseball cap and black jacket stands in a bathroom while holding a coffee mug .'),
#  ('mehrere menschen gehen im sonnenuntergan',
#   'five people walking with a multicolored sky in the background .'),
#  ('ein mann sitzt bei einem bier und wartet .',
#   'a man with black hair sits in a restaurant with a glass of beer .'),
#  ('polizist der grenzwache mit seinem hund',
#   'an officer in a reflective vest stands at the front of his van with his dog .'),
#  ('ein junge fährt fahrrad im schnee .',
#   'the &quot; white out &quot; conditions of snow on the ground seem to almost obliverate the details of a man dressed for the cold weather in a heavy jacket and red hat riding a bicycle in a suburban neighborhood .'),
#  ('fünf männer mit weißem hemd schwarzer hose und krawatte stehen vor einem auto .',
#   'five men , uniformly dressed in white shirts , tie and black slacks converse at the back of an open van .'),
#  ('einen mann mit kappe der in etwas hineingeht .',
#   'a tan man with a backwards hat looks at the camera while walking through a factory .'),
#  ('eine frau am fließband schaut in die kamera .',
#   'a caucasian man wearing a short-sleeved black shirt and a dark-skinned woman wearing a sleeveless dress are working at a conveyor .'),
#  ('einen mann der einen platz fegt .',
#   'man wearing a blue and white outfit , holding a broom , with a traditional asian architecture in the background .'),
#  ('ein auto wird kontrolliert und ein mann auf einem fahrrad schaut zu',
#   'two men in florescent vests are standing next to parked cars in front of a small building while one of them converses with a driver and a woman on a bike is seen riding by'),
#  ('2 kleinkinder sitzen auf einer wiese',
#   'a little girl in a pink shirt and a little girl in an orange shirt sitting in the grass .'),
#  ('ein mensch fährt auf einem gefährt über einen platz',
#   'a person in tan pants is inside a silver mobile object while people watch .'),
#  ('ein mann trifft eine großen roboter .',
#   'a man in black approaches a strange silver object containing a person , while many onlookers observe from behind a roped off barrier .'),
#  ('ein brautpaar steht auf einem gehweg .',
#   'bride and groom walking side by side out of focus on pathway next to brick building .'),
#  ('ein kleiner junge spielt im mcdonalds .',
#   'a little boy plays with a nintendo gamecube controller inside a mcdonald &apos;s .'),
#  ('hund am strand schüttelt sich trocken',
#   'white dog with brown ears standing near water with head turned to one side .'),
#  ('eine personen machen eine picknick .',
#   'a group of people picnicking at picnic tables in front of a playground .'),
#  ('das pärchen hat sich fotografieren lassen .',
#   'two asian or spanish people , a woman and a man , sitting together in front of a glass window as cars pass .'),
#  ('2 ältere damen beim mittagessen und hinter ihnen ist ein clown .',
#   'women are seated at a picnic table eating , while a man in a white t-shirt and a yellow and orange balloon design on his head stands in the background .'),
#  ('karatekämpfer führt einen kick aus',
#   'two people are demonstrating martial arts to a crowd and jumping over three youngsters who are crouched on the mat .'),
#  ('ein mann klettert an einer regenrinne hoch , während zwei jungen von einem balkon öl darauf schütten .',
#   'people on two balconies and a man climbing up a pipe towards the lower balcony getting liquid poured on him .'),
#  ('älterer mann mit roter jacke und bart auf der straße',
#   'a man with a red jacket is shielding himself from the sun trying to read a piece of paper .'),
#  ('zwei männer tragen ihre kinder auf dem rücken auf der straße .',
#   'two men are carrying children on their backs down the street on a sunny day in a nice neighborhood .'),
#  ('ein kleiner junge lacht in die kamera .',
#   'smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him .'),
#  ('einen schwarzen hund der über einen liegenden baum springt .',
#   'a mottled black and gray dog in a blue collar jumping over a fallen tree .'),
#  ('eine demonstration führt über eine große kreuzung .',
#   'men in the business suits are crossing the street , and there are people with placards are gathering on the street .'),
#  ('ein fahradfahrer fährt über eine kleine brücke .',
#   'a man in a red long-sleeved shirt bikes over a body of water on a bridge .'),
#  ('der mann mit sonnenbrille grillt .',
#   'a barefooted man wearing olive green shorts grilling hotdogs on a small propane grill while holding a blue plastic cup .'),
#  ('ein weißer hund mit braunen flecken der im schnee umherhüpft .',
#   'the white and brown dog is running over the surface of the snow .'),
#  ('eine gruppe menschen steht auf der straße .',
#   'man on scooter attracts attention from some of those in large crowd .'),
#  ('ein mann beim langlaufen der sich die ausstellung von bildern eines anderen mannes ansieht .',
#   'a person wearing skis looking at framed pictures set up in the snow .'),
#  ('eine gruppe klettert eine wand hoch und ein mann sichert .',
#   'several climbers in a row are climbing the rock while the man in red watches and holds the line .'),
#  ('die turnerin springt auf dem schwebebalken .',
#   'a young gymnast , jumps high in the air , while performing on a balance beam .'),
#  ('ein kind spielt mit einem kettcar .',
#   'a boy in a black t-shirt and blue jeans is pushing a toy three wheeler around a small pool .'),
#  ('eine frau mit kopftuch schaut durch ein fernrohr .',
#   'a woman with a red jacket and headscarf looks out over a scenic view of a bay through a set of pay binoculars on a viewing deck .'),
#  ('ein mann steht vor einem roten flugzeug',
#   'a man in a black coat walks past a red spaceship with a parking ticket stuck to its window .'),
#  ('ein hund rennt durch einen park .',
#   'large brown dog running away from the sprinkler in the grass .'),
#  ('vater mit kind , sitzen im einkaufswagen',
#   'a man and a little girl happily posing in front of their cart in a supermarket .'),
#  ('ein hund jagt einem ball hinterher .',
#   'a dog prepares to catch a thrown object in a field with nearby cars .'),
#  ('ein asiatischer junge hält sich die hand vor den mund .',
#   'a man wearing a green shirt and a dark colored vest is sitting at a table with a glass of water in front of him .'),
#  ('ein hund springt hoch um einen ball zu fangen .',
#   'a white dog is trying to catch a ball in midair over a grassy field .'),
#  ('2 männer beim bergabaenteuere .',
#   'two men are hiking in a forest where snow is partially covering the ground .'),
#  ('ein mann trägt einen kleinen holzschrank',
#   'an elderly man with facial hair and glasses , standing in his living room holding a hutch cabinet with glass doors .'),
#  ('zwei männer in einer wohnung sitze auf dem boden .',
#   'two guys sitting on the floor , with the guy in the green jacket reading a piece of paper .'),
#  ('der mann schaut auf die landkarte .',
#   'a bearded man wearing glasses , a red shirt , and a hat is reading a map while sitting in a car .'),
#  ('ein see mit einer ente davor zwei menschen',
#   'a large lake with a lone duck swimming in it with several people around the edge of it .'),
#  ('ein paar sitzt mit ihrem kind an einem baum .',
#   'a couple and an infant , being held by the male , sitting next to a pond with a nearby stroller .'),
#  ('zwei männer kontrollieren einen weiteren .',
#   'three men are standing at night near a black car near a shelter filled with bicycles .'),
#  ('ein hund im wasser', 'a black lab with tags frolicks in the water .'),
#  ('ein mann bohrt in eine eisdecke hinein .',
#   'a man is drilling through the frozen ice of a pond .'),
#  ('2 hunde beim spielen am strand',
#   'two different breeds of brown and white dogs play on the beach .'),
#  ('ein mann kletter an einem eisigen steilhang .',
#   'an ice climber in a blue jacket and black pants is scaling a frozen ice wall .'),
#  ('drei junge leute gehen in der natur spazieren .',
#   'two young men and a young lady walk through a field near the water .'),
#  ('der räumt den gehweg von schnee .',
#   'a man in black attire shovels snow into the street , disregarding all public safety .'),
#  ('ein hochzeitspaar schneidet ihre torte an .',
#   'a couple in their wedding attire stand behind a table with a wedding cake and flowers .'),
#  ('ein hund trägt etwas grünes im maul',
#   'a black dog carries a green toy in his mouth as he walks through the grass .'),
#  ('kinder un ihrer mütter sitzen an martkständen .',
#   'a group of woman and children are standing or sitting in front of rows of vegetables .'),
#  ('ein sänger in gelbem shirt schreit ins mikrofon .',
#   'a band is playing in front of an audience and the singer is wearing an orange shirt and has tattoos on his arm .'),
#  ('ein junge auf einem skateboard in der luft .',
#   'a young woman with short blond-hair wearing jeans and a striped long-sleeved sweater jumping in midair on a skateboard with trees in the background .'),
#  ('ein mann und ein kind sitzen in einem kanu .',
#   'a man and a little boy in blue life jackets are rowing a yellow canoe .'),
#  ('eine frau und ein kind sitzen auf stühlen auf dem gehweg und eine frau steht daneben',
#   'a little boy looks at the camera while a woman behind him seems to be laughing very hard and the woman on the right has a big smile on her face .'),
#  ('3 arbeiter stellen einen grossen metallpfosten auf',
#   'a construction site on a street with three men working .'),
#  ('2 männer sitzen auf einer bank',
#   'two men , one younger guy with a yellow shirt that has luggage and the other and older guy , are sitting on a bench in front of a large building that has a billboard for glasses and sunglasses .'),
#  ('eine gruppe von menschen , die eine regenbogen-fahne halten .',
#   'during a gay pride parade in an asian city , some people hold up rainbow flags to show support .'),
#  ('ein mann betrachtet die ware einen fischverkaufsstands .',
#   'a young man in a blue sweater cleaning fish while three other men watch , one a man a cigarette , or match in his month .'),
#  ('eine frau mit grünem kleid beim singen .',
#   'woman in a green dress with a white top and red-hair singing in a room with a blue roof while band equipment is being prepared .'),
#  ('vier junge leute sitzen auf einer treppe .',
#   'four college-aged individuals - two males and two females - sitting on the concrete steps outside of a brick building'),
#  ('2 hunde sitzen auf dem boden einer hat ein spielzeug im maul',
#   'the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway .'),
#  ('einen jungen , der mit einem hockeyschläger im tor steht .',
#   'a young male kneeling in front of a hockey goal with a hockey stick in his right hand .'),
#  ('ein mann sitzt vor einer statue und liest zeitung .',
#   'the man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading .'),
#  ('ein kind steht an einem gitter .',
#   'a toddler in a blue shirt with red shorts and hat looks out from behind a fenced in area of a brick patio .'),
#  ('eine frau , die mit ihren drei hunden spielt .',
#   'three dogs are standing in the grass and a person is sitting next to them'),
#  ('ein mann steh vor einem riesigen haus',
#   'there is a skyscraper in the distance with a man walking in front of the camera .'),
#  ('eine frau schiebt einen kinderwagen durch einen park .',
#   'a woman wearing a brown dress with a matching turban is pushing a toddler through a park in his stroller .'),
#  ('; mann neben melonenstand , wartend auf kunden',
#   'a asian male wearing a red shirt is sitting next to a grocery stand selling fruits .'),
#  ('zwei kinder die essen',
#   'a young child with a band-aid on his head sits eating at a small white table with a little girl eating off a yellow plate .'),
#  ('ein junge isst ein stück pizza .',
#   'a small boy putting something in his mouth with both hands .'),
#  ('ein gitarrist steht auf einer bühne .',
#   'a man with wild hair rocks a show playing a guitar center stage .'),
#  ('die frau mit dem helm steht vor dem zaun und schwingt den schläger .',
#   'a person in a green outfit and helmet is swinging a baseball bat at a tennis ball in front of a fence .'),
#  ('ein mann spielt auf einer e-gitarre .',
#   'a man in black with long hair playing a guitar with stickers on it .'),
#  ('betonierer bei der arbeit',
#   'a man in a black shirt crouches next to a dirty unfinished concrete edge while several shovels and other tools lean against a tree nearby .'),
#  ('eine frau sitzt am tisch beim romantischen essen',
#   'a caucasian young woman in a white hooded sweatshirt sits at a table set for two in a lowly lit restaurant .'),
#  ('die frau liegt auf der roten decke im gras neben dem liegenden fahhrad .',
#   'a woman in a blue shirt and sunglasses lies on a red blanket in a grassy field with a bike set down next to her .'),
#  ('ein mann auf einer hängebrücke in der dämmerung .',
#   'someone is standing on a long bridge with a cloudy blue sky in the background .'),
#  ('ein kind läuft über eine wiese .',
#   'young white boy on a grassy area with a sad expression on his face .'),
#  ('ein mann und ein hund stehen vor einem grill und schauen nach oben .',
#   'a man is cooking what appears to be green beans in a grill basket on a grill with a yellow lab standing by him while someone takes a picture from above .'),
#  ('3 kletterer , die die aussicht auf dem berg genießen .',
#   'three people are on a hilltop overlooking a green valley .'),
#  ('mehrer personen übwequeren eine brücke .',
#   'a group of tourists is crossing a bridge that connects a walking path to a trail of nature .'),
#  ('ein kind schaut über eine reling einem bootrennen zu .',
#   'a young boy wearing a jersey looks down over a ledge at many boats in the water .'),
#  ('ein mann und 2 mädchen sitzen zusammen und unterhalten sich',
#   'a older man holds an object and is looking at two young girls that sit across from him at a table that is outside .'),
#  ('ein paar hält händchen und lacht in die kamera .',
#   'a man is holding the hand of a woman up to his mouth in front of some buildings while another man looks on .'),
#  ('mann mit fagott',
#   'a man with glasses is sitting a chair playing the oboe while a man in a purple shirt plays percussion and spectators look on .'),
#  ('passanten und radfahrer bevölkern eine straße in einer asiatischen stadt .',
#   'a man in the foreground wearing a white shirt and black pants riding a bicycle with a basket in a busy street .'),
#  ('ein mann arbeitet an einem haus .',
#   'a man on a ladder is painting a brick wall in a warehouse .'),
#  ('2 männer in einer u-bahn .',
#   'a blond-haired man with glasses and a blank tank top is sitting next to another man with glasses and headphones while sitting on a train .'),
#  ('eine junge asiatin überquert mit ihren tüten eine straße .',
#   'juggling her shopping bags and betty boop backpack and young woman crosses a city street .'),
#  ('sechs menschen sitzen essend um einen tisch .',
#   'several asian people are eating together around a table .'),
#  ('eine frau mit grossen gemüsekorb auf dem kopf',
#   'a woman with flowers in her hair balances a large bowl of assorted fruits on her head .'),
#  ('einen man der ein loch grabt',
#   'a man wearing a gray jacket and blue work pants is standing in a hole in the ground'),
#  ('4 kinder auf einem fahrrad .',
#   'a shirtless young boy on a bicycle too big for him being supported by 3 other young shirtless boys in a grass field .'),
#  ('ein mann und eine frau vor einer wanne aus der es raus dampft .',
#   'a man in a bandanna and a dirty t-shirt , and a woman in a graphic t-shirt , are standing next to a oblong hole with smoke coming out .'),
#  ('ein baby wird von jemandem auf dem unterarm gehalten .',
#   'this little baby girl dressed whimsically in striped pantaloons is pictured so that one must ask which is bigger , her feet or her sleepy smile .'),
#  ('einen schwarzen mann mit kopfschmuck und einem nagel durch die unterlippe .',
#   'an african individual is looking into the camera while dressed in varying beads and decorations that have a cultural relevance .'),
#  ('ein mann mit einem schwert steht auf einer wiese .',
#   'a samurai warrior in full black dress takes his sword from the sheath on an outdoor training mat .'),
#  ('fünf frauen sitzen auf einer mauer vor dem strand .',
#   'a couple of several people sitting on a ledge overlooking the beach'),
#  ('5 leute beim wandern',
#   'a group of men and women are hiking through a dried up river bed littered with large rocks , which runs between two rocky walls in a dense green forest .'),
#  ('ein mann und ein metallgestell stehen in einem saal .',
#   'a man with a badge is standing on a wood floor next to a structure .'),
#  ('2 frauenin langen kleidern beim reinigen eines platzes',
#   'two women in colorful dresses are sweeping water out of the street while a man watches .'),
#  ('zwei mädchen hocken vor bluemenbeeten .',
#   'two separate women , one wearing a white top and black pants , the other wearing all black and a pair of pink flip-flops , kneel on a gray brick sidewalk path in front of green and red bushes .'),
#  ('ein kleines ; ädchen läuft über eine wiese .',
#   'a young girl wearing a multicolored holding an orange ball in her right hand walking through bright green grass behind a house'),
#  ('ein kleiner junge sitzt auf dem boden',
#   'a young child wearing a blue shirt and sandals playing with a red toy while sitting on the floor .'),
#  ('zwei jungs beim skateboarden .',
#   'a little boy skateboarder is doing a trick on his board while another young skateboarder watches .'),
#  ('ein kleiner junge und ein kleines mädchen sitzen auf der wiese',
#   'two little children , one boy and one girl , laugh as they sit on the grass .'),
#  ('eine frau sitzt mit einem getränk auf einer bank vor einem auto und reicht jemandem die hand .',
#   'young woman holding a bottle , reaching out from a bench to shake a man &apos;s hand .'),
#  ('ein mann steuert einen ausflugsbus .',
#   'man talking on a microphone and a crowd of people in front of him .'),
#  ('eine frau rudert im kanu .',
#   'a girl paddling down a large river , as seen from behind her .'),
#  ('ein mädchen mit zwei zöpfen spielt im meer .',
#   'a girl with pigtails is playing in the ocean by the beach .'),
#  ('zwei personen sitzen an einem tisch mit dessert .',
#   'two people sitting beside each other at a table with food on it smiling .'),
#  ('ein gedeckter tisch mit dessert .',
#   'white wine and appetizers on are displayed in an upscale restaurant .'),
#  ('die beiden bauarbeiter mit den helmen sitzen auf dem gerüst vor dem gebäude .',
#   'two construction workers are sitting up on the side of a building .'),
#  ('der kleine junge hält den mixer .',
#   'a smiling little boy holds a hand mixer in a bowl .'),
#  ('zwei kinder spielen in einer pfütze .',
#   'two boys , one with a yellow and orange ball , play in some water in front of a field .'),
#  ('ein kleinkind sitzt im zug und betrachtet eine zeitschrift über zugreisen .',
#   'a young girl sits on a seat and looks at a train pamphlet .'),
#  ('2 mädchen sitzen aif einem stuhl und lachen .',
#   'two asian girls laughing , as the girl on the right holds an instrument .'),
#  ('mehrer personen joggen durch einen park .',
#   'several people jogging outside on a sunny day in what seems to be a neighborhood , could be part of a marathon .'),
#  ('ein kind springt ins blaue wasser .',
#   'a kid jumps off the diving board and into the swimming pool below .'),
#  ('ein blonder hund rennt einen strand entlang .',
#   'a white dog is running down a rocky beach .'),
#  ('ein mann nimmt ein bad in einer holzwanne',
#   'a young man is bathing , with only his shorts on , in a large wooden pale .'),
#  ('ein mann liegt auf einer bank neben der strasse',
#   'a person is sleeping on a bench on the sidewalk , across the street from a bus stop .'),
#  ('zwei mädchen die an einem baum spielen .',
#   'two young girls are playing in the forest ; the younger one is climbing a short tree and is about 2 feet off the ground .'),
#  ('ein junge schläft auf dem autorücksitz .',
#   'it looks as though a soldier is sleeping in a car on his way home after a deployment .'),
#  ('eine frau schläft auf dem autorücksitz .',
#   'pink shirted woman sleeping in a car with blue and white blanket on her .'),
#  ('einen mann , der einen pfannkuchen in die höhe schmeißt',
#   'one man wearing a white shirt is flipping a pancake by flinging it into the air .'),
#  ('die feuerwehrmänner stehen vor dem feuerwhehrwagen nachts auf der straße .',
#   'firefighters converse with a man at the scene of an emergency .'),
#  ('feuerwehrmänner beim einsatz .',
#   'a few firefighters , wearing black , yellow , and pink jackets , standing next to a firetruck .'),
#  ('mehrer personen halten sich am strand auf .',
#   'a man is kneeling down with a child on a beach where bright blue and red boats are stationed in the background .'),
#  ('zwei männer arbeiten in einem gang .',
#   'a man in an orange hard hat and vest looks at an object in his hand while the man next to him stands on a ladder in order to reach the ceiling .'),
#  ('eine verkäuferin an einem zeitungsstand .',
#   'a newsstand so packed with magazines , candy and coke-a-cola products that the smiling woman working behind the counter is easy to miss .'),
#  ('ein bauarbeiter steht in einer riesigen sandgrube .',
#   'a large earth moving machine creating a track with a man watching it closely with what looks like surveying equipment .'),
#  ('2 bäcker sitzen geschafft in der bäckerei herum',
#   'a man sitting down with this head resting on his fists next to a man with his eyes closed and his together with dough sitting on a table in front of them both .'),
#  ('fünf personen sitzen an einem see .',
#   'four men are sitting near a tree talking while another stands looking at a body of water and another is rowing a boat .'),
#  ('ein kind mit badehose steht am strand .',
#   'a young boy in swimming trunks is walking with his arms outstretched on the beach .'),
#  ('ein skifahrer der auf einer bergkuppe steht und die aussicht geniest .',
#   'a skier is overlooking the beautiful white snow covered landscape .'),
#  ('radfahrer auf einer straße machen stunts .',
#   'kids riding on their bicycles near a mound of dirt with a hovel from a backhoe in front of the mound .'),
#  ('männer fahren einviev radrennen .',
#   'a bunch of people in racing gear and helmets racing bicycles around a corner on wet pavement .'),
#  ('eine junge fährt mit dem fahrrad über einen erdhügel .',
#   'a boy in a pink t-shirt is riding a bike over a sand pile while two others are riding in the street .'),
#  ('ein alter mann mit stock bückt sich um etwas aufzuheben und wird dabei gestützt von einem jüngeren mann .',
#   'elderly man with cane bends down to look at some plants and is steadied from behind .'),
#  ('ärzte in der chirugie .',
#   'a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs .'),
#  ('ein hund fängt einen frisbee .',
#   'a black and white dog is attempting to catch a yellow and purple object in a low cut yard .'),
#  ('zwei hunde laufen über einen sandstrand .',
#   'a white and black dog and a brown dog in sandy terrain .'),
#  ('ein bahn auf derbowlingbahn',
#   'a man in an all black outfit just threw a bowling ball down a lane towards the center of the bowling pins .'),
#  ('reitender mann auf schimmel durch die steinwüste',
#   'a man in a black shirt is riding a mule trough the desert , with the sun shining in the background .'),
#  ('ein paar schläft auf dem sofa .',
#   'two tired-looking men relax on a couch near a wooden trestle table with a coffee cup on it .'),
#  ('ein mann im gelben trikot wirft einen speer .',
#   'a man in a yellow shirt and black shorts getting ready to throw a javelin .'),
#  ('viele menschen sitzen auf einer wiese und sehen ballonen zu wie sie starten .',
#   'seven large balloons are lined up at nighttime near a crowd .'),
#  ('eine frau liest eine zeitschrift und eine frau sieht ihr zu .',
#   'two brunette women in jackets sitting against a wall and looking at the same magazine .'),
#  ('zwei männer zünden in dunkeln kerzen an .',
#   'two men are squatting with one man lighting a stick from a candle flame and the other man has his hands folded looking at the ground while a person wearing a bracelet has a phone to their ear .'),
#  ('der mann und die frau gehen auf dem gehweg vor den anderen menschen .',
#   'a young man is walking through a busy street beside a mall .'),
#  ('ein junge mit helm fährt mit seinem fahrrad',
#   'a little boy rides a bike down a hill on a miniature dirt bike .'),
#  ('menschen sitzen nachts auf einer beleuchteten veranda .',
#   'a group of people sit around a table outside on a porch at night .'),
#  ('ein mann spielt am strand mit zwei schwarzen hunden .',
#   'a man in a brown shirt and dark shorts plays on the beach with his two black dogs .'),
#  ('ein mit schaum bedeckter athlet wird gesäubert .',
#   'a child covered in foam is climbing on a black inflatable ramp .'),
#  ('menschen die auf booten party feiern .',
#   'a couple is sitting in a blue raft watching a lot of people in bathing suits on a boat .'),
#  ('eine junge frau im bikini auf einem boot versucht mit einem fußtritt einen mann ins wasser zu stoßen .',
#   'a girl with blond-hair is holding a bottle and wearing a blue and green floral bikini on a boat .'),
#  ('ein kind der im pool rutscht',
#   'a boy in blue swimming trunks slides down a yellow slide into a wading pool with inflatable toys floating in the water .'),
#  ('mann wirft kleines kind spielerisch in die luft',
#   'a man in water throwing a little boy up in the air and waiting for him to come down so he can catch him .'),
#  ('viele männer die in einem fahrzeug mit fahren',
#   'a large group of people traveling down a countryside road in the back of a small pickup truck while one person is walking along side the truck .'),
#  ('2 köche in ihrer küche angestrengt arbeitend',
#   'two people are preparing food in a restaurant kitchen .'),
#  ('zwei kleine jungs in einem zelt schauen in die kamera .',
#   'two young boys are looking at the camera , one smiling , the other sticking his tongue out .'),
#  ('ein mann schweißt an einem stahlträger .',
#   'a person with brown pants is sitting around a fenced area that has sparks flying .'),
#  ('eine person lehnt an einem großen kreuz und schaut auf einen see .',
#   'a woman is resting against a cross shaped pole while looking towards a large body of water .'),
#  ('junge menschen sitzen und stehen auf einer wiese .',
#   'a group of people on a riverbank some sitting on the grass some standing .'),
#  ('männer schippen schnee .',
#   'two men shoveling snow off a railroad track dressed in bright orange snowsuits .'),
#  ('ein mädchen mit pferd , die vor einem lagerfeuer stehen .',
#   'a blond horse and a blond girl in a black sweatshirt are staring at a fire in a barrel .'),
#  ('bauarbeiter reparieren schienen .',
#   'a group of construction workers dressed in orange safety vest sit on the ground assembling a railroad track .'),
#  ('2 männer reparieren ein auto .',
#   'two gentlemen in baseball caps and shirts , work on the engine of an old , rusted vw beetle .'),
#  ('eine frau bastelt auf dem boden .',
#   'a man kneels on the ground doing some sort of project on his own .'),
#  ('3 hunde stehen zusammen und einer beschnuppert den anderen',
#   'a large brown dog is pushing a small boston terrier with his face while anouther dog watches .'),
#  ('ein mann und eine frau sitzen auf einem steg .',
#   'a man and woman sitting on a deck next to a lake .'),
#  ('schienen für strassenbahn werden gelegt',
#   'there are workers laying out the tracks for a trolley .'),
#  ('ein bauarbeiter schweißt etwas .',
#   'a construction worker in a neon vest is working with electrical equipment while sparks fly .'),
#  ('eine junge frau tuscht ihre wimpern .',
#   'a woman with red-brown hair and dark painted fingernails is carefully applying mascara .'),
#  ('der weiße hund liegt auf dem boden .',
#   'a white dog is resting its head on a tiled floor with its eyes open .'),
#  ('eine frau klettert eine wand hoch .',
#   'a woman in a yellow shirt and green shorts is climbing an artificial red wall whilst wearing a safety harness .'),
#  ('motorräder stehen zum verkauf auf dem gehweg .',
#   'looks like everyone is getting good gas mileage here with all these beautiful scooters !'),
#  ('ein fliegende hilikopter',
#   'the regional park police helicopter is preparing to land .'),
#  ('ein mann klettert auf ein haus .',
#   'an older , male construction worker wearing a yellow vest climbing down from the roof of a building onto scaffolding .'),
#  ('viele leute beim geselligen abend',
#   'a group of people are either standing or sitting , some are wearing hats and scarves , while some are not .'),
#  ('kinder die auf dem luft springer springen im wasser',
#   'a young boy jumping and a young girl sitting in an inflatable pool .'),
#  ('vier kinden sitzen auf einem landwirtschaftlichen fahrzeug .',
#   'several children playing on a polaris vehicle outdoors .'),
#  ('eine ältere frau kocht am herd',
#   'an older woman stir fries vegetables in a home kitchen , with a counter crowded with jars and bottles in the background .'),
#  ('eine frau sehr leichtbekleidet steht auf dem gehweg und einige andere personen stehen daneben',
#   'the girl in the salmon colored bikini is standing next to two young people ; one is wearing a black outfit and the other is drinking pop .'),
#  ('2 männer auf skien durch den verschneiten wald',
#   'two people wearing yellow jackets crosscountry skiing .'),
#  ('zwei skifahrer steigen einen berg hoch .',
#   'a lone skier is making their way up a mountain .'),
#  ('ein kleiner brauner hund läuft auf der straße .',
#   'a light brown dog runs down a path happily .'),
#  ('eine sitzende frau schreibt in einen buch .',
#   'a girl sitting on the steps of a building wearing a green short-sleeve shirt , blue jeans , flip-flops holding a cup and writing in a journal with her purse sitting at her feet .'),
#  ('menschen in der stadt',
#   'people walk across a street as utility workers fix a light .'),
#  ('eine dame sitzt auf einem thron .',
#   'woman sitting in a red chair with a dressy purple dress on and a book sitting on the arm rest .'),
#  ('menschen genießen die abendstimmung beim angeln .',
#   'a woman stands with children on a boardwalk at night overlooking the sea .'),
#  ('mehrere jungen spielen ein ballspiel mit schlägern .',
#   'six males playing a game in the sand with wooden paddles .'),
#  ('drei kleine kinder spielen mit einer jungen frau .',
#   'a woman is laughing as two small boys play around her and a small girl climbs up her back .'),
#  ('ein mann repariert ein altes auto und ein junge schaut zu .',
#   'a man in a black shirt and black jeans and a little boy are taking a look inside a green truck &apos;s engine while it is parked in a grass field with a gas tank in front of it .'),
#  ('eine frau die mit ihrem braunen pferd im schnee reitet .',
#   'a woman dressed in a blue jacket and blue jeans rides a brown horse near a frozen lake and snow-covered mountain .'),
#  ('eine frau sitz auf der kutsche mit 2 pferden davor gespannt',
#   'two golden brown horses pull a sleigh driven by a woman in a blue coat .'),
#  ('eine frau macht bergsteigen .',
#   'a person climbs a tall , flat mountain while holding onto a safety rope .'),
#  ('bergwanderer sitzen auf dem boden vor einem berg',
#   'a group of hikers are resting on the ground in front of some mountains .'),
#  ('eine junge frau hat mit kreide eine straßenmalerie erstellt .',
#   'a woman wearing a blue dress is drawing a picture of a boy and a girl on the sidewalk with sidewalk chalk .'),
#  ('eine frau tritt einem mann ins gesicht .',
#   'three young adults are sitting around , with the girl pretending to kick one of the guys in the face while laughing , and the guy behind him looks like he &apos;s in midsentence .'),
#  ('die kleinen kinder jubeln und heben die hände .',
#   'a group of african american children with their arms above their heads and happy expressions on their faces .'),
#  ('ein mann mit badehose springt von einer brücke ins wasser .',
#   'a shirtless man jumping off a large concrete structure into a river with his friends watching from the structure .'),
#  ('eine frau näht mit einer weisen nähmaschine .',
#   'a young black person wearing a green shirt and a jacket using a sewing machine .'),
#  ('eine frau spricht mit einem jungen .',
#   'an oriental woman with her fist raised in the air , other oriental people around her , and a black moped beside her .'),
#  ('eine verkäuferin arbeitet in einer markthalle an einem obst- und gemüsestand .',
#   'a woman smiles while holding several green peppers at a grocery stand .'),
#  ('ein mann mit gehstock sitzt in einem stuhl .',
#   'an elderly woman with a cane sits in a large wooden chair next to a weaving loom , in a log cabin .'),
#  ('ein junge der auf einer wiese sitzt und seifenblasen macht .',
#   'a little boy in a striped shirt and blue jeans is blowing bubbles from a red container .'),
#  ('ein kleiner junge spingt in einen brunnen',
#   'a young boy is jumping through water being sprayed up from the ground .'),
#  ('ein hund sitzt auf der wiese herum',
#   'the dog is running out of the tunnel on a dog obedience course .'),
#  ('2 hunde rennen auf der wiese',
#   'a yellow dog and a black and white dog are running in the dirt .'),
#  ('zwei männer stehen vor einem grill .',
#   'two men barbecuing on the grill with a little girl playing in background .'),
#  ('ein mädchen springt am strand in die brandung .',
#   'a girl in a floral bathing suit jumping on the beach in front of the waves .'),
#  ('ein mädchen im blauen badeanzug balanciert am strand auf einem holzgeländer .',
#   'a little girl in a blue swimsuit is walking along a wooden fence next to a sandy beach .'),
#  ('ein junge steht neben einem mützenständer .',
#   'a man in a white shirt is outside leaning against a rail with hats hanging beside him .'),
#  ('ein hund spielt mit einem wasserstrahl .',
#   'a black and white dog is being soaked with a jet of water in a blue paddling pool .'),
#  ('ein kind taucht im wasser', 'a smiling boy swims underwater in a pool .'),
#  ('ein mann im schwarzen hemd der sich mit einer frau unterhält .',
#   'a man gestures while facing a woman wearing glasses as they sit inside a restaurant that includes a yellow wall .'),
#  ('drei männer und snowmobile im verschneiten wald .',
#   'two helmeted men sit on yellow snowmobiles while another man stands behind watching .'),
#  ('ein mann der mit einer schaufel ein dach vom schnee befreit .',
#   'a man shovels snow off of a roof while another stands in the contraption that allowed them to reach the high place .'),
#  ('ein mann baut stühle auf .',
#   'a young boy wearing a black shirt , brown pants and a black watch has his hand on a white folded chair which is on the top of a large stack of similar folding chairs .'),
#  ('zwei beleuchtete moderne gebäude stehen hinter einer heruntergekommenen kulisse .',
#   'two buildings beyond a concrete wall facing a walkway with a woman talking on a cellphone .'),
#  ('ein mädchen pustet eine pusteblume .',
#   'a very young girl playing with a bubble-blowing wand , holding a bottle of bubble solution and walking through a park or field .'),
#  ('3 personen fahren quads',
#   'three people on atvs in a brown field turn their heads to look at the camera .'),
#  ('ein quadfahrer vollführt mit seinem quad einen sprung .',
#   'a person is riding an orange atv in a large empty field .'),
#  ('ein motorcross-fahrer springt auf einem feld .',
#   'a person dressed in a tan jacket jumps a quad over a harvested cornfield in front of a small out building .'),
#  ('eine frau sitz am strand',
#   'a girl is sitting on the beach and appears to be approaching a hit on the head by a plastic inflated hammer .'),
#  ('ein mann macht pfannkuchen in einer pfanne',
#   'a man is cooking a square pancake : he lifts it with his fingers and a spatula to check to see if it is done .'),
#  ('zwei frauen umarmen sich .',
#   'two women hugging in a grassy , fenced field with a cow &apos;s behind in the background .'),
#  ('zwei hafenarbeiter weisen auf ein großes schiff .',
#   'there are two men in orange life vests signaling to a cruise ship docking at a pier .'),
#  ('ein mann sitzt auf einer bank und telefoniert .',
#   'a man in sandals and white cardigan sits on a green bench while talking on his cellphone .'),
#  ('einen mann , der auf der bühne singt .',
#   'a man wearing a white tank top sings into a microphones on a stage with a crowd watching .'),
#  ('männer reiten auf einem elefanten .',
#   'three men are riding on an elephant with a shack in the background and two of them are wearing hats .'),
#  ('mann bei der autoreparatur',
#   'a man in a gray camouflage shirt and gray pants sits under the hood of a blue truck .'),
#  ('zwei geschweister amüsieren sich .',
#   'a young boy , wearing goggles and a heads-up light , and a young girl , are smiling .'),
#  ('viele junge menschen auf einer internationalen demonstration',
#   'young individuals in uniforms are gathering under the flags of several different countries .'),
#  ('ein kind steht vor einer heizung und weint .',
#   'a baby is crying while holding on to the side of a crib .'),
#  ('ein junge mit ball läuft über den rasen in einem park .',
#   'a boy wearing a white t-shirt walks on the grass and carries a soccer ball .'),
#  ('eine dame , die bei einem mann eis bestellt .',
#   'a woman is at an ice cream shop and she is waiting for the man to scoop her ice cream .'),
#  ('die menschen essen .',
#   'a man is eating alone at a table near another table where a man and woman are seated .'),
#  ('mehrere menschen tragen eine große usa-flagge .',
#   'people are standing around an american flag that is spread out , facing the wrong direction .'),
#  ('eine frau malt mit wasserfarbe ein bild .',
#   'a young girl with braids is painting with water colors on a white paper on the wall .'),
#  ('ein fahrradfahrer fährt einen berghang hinunter .',
#   'a man in aerodynamic gear riding a bicycle down a road around a sharp curve .'),
#  ('ein mädchen rennt über eine wiese .',
#   'a little girl in a blue jeans vest is running across the grass and laughing .'),
#  ('ein mann hält seine brille in der hand',
#   'a gray and black-haired male is holding his glasses in one hand while looking at something in the other hand ; surrounded by numerous amounts of machines .'),
#  ('ein paar , dass sich auf einer rolltreppe küsst .',
#   'a couple show their affection on an escalator by embracing and kissing one another .'),
#  ('männer spielen rugby .',
#   'a rugby game being played , one man in a green jersey is being lifted up by his teammates with the ball , while a competitor in a red jersey is similarly lifted to tackle him .'),
#  ('zwei arbeiter schieben schubkarren auf einer ausgrabungsstelle .',
#   'two men pushing wheelbarrows , two men looking at them , they are in the desert near some block construction buildings .'),
#  ('fünf verkleidete personen sitzen auf einer bank .',
#   'a young group of friends adorned with face paint and feathered headbands sit on a bench .'),
#  ('ein mann geht auf ein geschäft zu und schaut in die kamera .',
#   'a woman is surprised to have her picture taken on this fall day outside spaulding &apos;s women &apos;s store .'),
#  ('ein mann steht auf einem gehweg und hält ein bedrucktes papier vor sich .',
#   'a man wearing a black jacket and gray slacks , stands on the sidewalk holding a sheet with something printed on it in his hand .'),
#  ('ein schwarzer hund spielt auf einer grünen wiese .',
#   'a black dog playing fetch with a ball of rope .'),
#  ('mädchen mit ( hoffentlich ) spielzeugpistole',
#   'a young girl is looking through an old fashioned video camera .'),
#  ('eine frau die sitzt und ein buch liest .',
#   'a woman scantily dressed in handsome homemade-looking clothing sits on a wooden step and reads brazilian author coelho .'),
#  ('ein mann spielt e-gitarre .',
#   'a musician plays his electric guitar surrounded by sound equipment .'),
#  ('zwei eishockeyspieler und der torwart am tor .',
#   'two hockey teams are shown at the goal where the white team is stopping a goal being made by the blue team .'),
#  ('zwei personen laufen an einem strand entlang .',
#   'a small child and an adult walk on the beach in front of ocean waves .'),
#  ('ein mann sitzt vor einem schaufenster .',
#   'grocery store employee , dressed in a red apron &amp; amp ; a baseball cap , sits on a ledge in front of the store .'),
#  ('ein hund fängt im sprung eine frisbee .',
#   'a brown and white dog catches a frisbee in it mouth in front of a group of people .'),
#  ('zwei personen stehen sich auf einem tennisplatz am netz gegenüber .',
#   'two men in a tennis court in a city are standing on either side of the net talking to each other .'),
#  ('die menschen sitzen und schauen den artisten zu .',
#   'two jugglers using flaming torches are performing for a crowd of people who are sitting on steps .'),
#  ('zwei kleine kinder hüpfen einen weg entlang .',
#   'a young boy in a yellow shirt is jumping in a grassy area with a younger boy , in a white shirt , standing behind him .'),
#  ('einen kleinen jungen der mit steinen spielt .',
#   'a toddler sitting on a pile of rocks holding a rock at a beach .'),
#  ('der junge mit dem eishörnchen in der hand sitzt vor der frau und zieht eine grimasse für die kamera .',
#   'a kid wearing a gap hat looks into the camera with a funny face and ice cream cone in his hand while a woman looks on from behind him .'),
#  ('ein mann hängt poster an einem marktstand auf .',
#   'five men , one wearing a white shirt standing on something , hanging up a picture of a child .'),
#  ('ein älterer mann mit weißem hut spielt mit einem kleinen kind am strand im sand .',
#   'older man in a hat , yellow shirt and dress slacks playing in the sand with a young boy .'),
#  ('ein kind unter dem wasser trägt ein taucherbrille',
#   'a blond child is wearing blue goggles and a green speedo tank top while swimming underwater .'),
#  ('viele rollerfahrer auf einer straße .',
#   'two asian men are riding on a motorcycle in the midst of a crowd full of other motorcycle riders .'),
#  ('drei personen die ein spiel spielen .',
#   'a man and two women are playing a board game at a wooden table while drinking alcohol .'),
#  ('junge menschen stehen im freien und trinken .',
#   'several young people are standing around drinking beverages at some kind of outdoors gathering with food .'),
#  ('ein mann klettert eine felswand hinauf .',
#   'the young man with the white t-shirt and jeans is rappeling up the rock wall .'),
#  ('ein mann klettert .',
#   'a climber wearing a blue helmet and headlamp is attached to a rope on the rock face .'),
#  ('ein kind spielt an einem brunnen .',
#   'the little girl is playing with a toy in a public fountain .'),
#  ('ein hund springt über pfeiler am strand .',
#   'a black dog runs along the beach and jumps over a wood barrior .'),
#  ('viele menschen in einem restaurant .',
#   'people are eating in a cafeteria with a wood beam and glass ceiling .'),
#  ('ein junges mädchen klettert aus der kasnalisation hoch .',
#   'a woman is standing in a rough hewn structure with a round opening with her head sticking out above the opening .'),
#  ('ein vogel sitzt auf einer menschenhand , auf der auch sonnenblumenkerne liegen .',
#   'black and white bird standing on hand of someone holding sunflower seeds'),
#  ('eine frau bei einem tennisspiel .',
#   'the ball boys are waiting on the side lines of the tennis court while they watch the lady hitting the ball .'),
#  ('ein hund liegt am strand .', 'a brown dog is running in the sand .'),
#  ('ein mann mit hut steht auf einem hausdach',
# ...
#   'a drayton manor theme park roller coaster is shown accelerating downwards vertically on a red colored track with several visible people making either happy , excited or scared faces .'),
#  ('der kleine junge steht auf dem feld und lehnt sich auf den kürbis .',
#   'a young boy examines a field of pumpkins , with some already in his wheelbarrow .'),
#  ('ein mann mit gitarre entspannt sich im park .',
#   'a man in jeans and sandals sits outside near trees and a goose and plays a string instrument .'),
#  ('ein mädchen das schreit .',
#   'the girl in the purple top and shorts , wearing a hat , is laughing .'),
#  ('eine junge frau geht am strand entlang .',
#   'a girl in a bikini walks along the beach with huge clouds and a sandy beach behind her .'),
#  ('zwei männer beim bilder anschauen .',
#   'a man in a torn gray jacket holding some papers looks downward while standing behind a short-haired man in a brown shirt .'),
#  ('eine band spielt auf einer bühne vor publikum .',
#   'four men , two of them with guitars , perform on a stage while several people with their hands in the air watch .'),
#  ('ein mann fährt im eiswagen die strasse entlang',
#   'an ice cream truck with an open door is driving through a residential neighborhood .'),
#  ('ein junge mit badehose bekleidet steht unter einer dusche .',
#   'a boy is squinting while being sprayed with water from a flat ground surface .'),
#  ('ein asiatisches kind springt fröhlich ins wasser .',
#   'a child in white briefs is pictured jumping in midair above the water of a rive , with trees in the background .'),
#  ('zwei kinder auf einem gehweg , einer hat ein fahhrad .',
#   'a boy is standing on a sidewalk with his bike .'),
#  ('ein kleiner junge spielt auf einem spiel gerüst auf dem spielplatz',
#   'a young boy is playing on a piece of playground equipment that features tires which he must step in and out of , while keeping his balance .'),
#  ('ein taucher taucht zusammen mit einer meeresschildkröte .',
#   'a scuba diver who has descended to the bottom of the ocean floor reaches out to pet a large sea turtle .'),
#  ('eine afrikanische familie mit gepäck marschiert auf einer straße .',
#   'a line of native african villagers traveling down a dusty road .'),
#  ('einen braunen hund der in der wiese sitzt .',
#   'the dog is sitting on the side of the hill .'),
#  ('ein kind krabbelt auf dem boden .',
#   'a baby wearing a white shirt is crawling on the ground next to a table .'),
#  ('ein mann und ein junge laufen auf einer straße .',
#   'a man wearing dark clothing is talk to a young boy while they are walking down the sidewalk .'),
#  ('eine antike figur und im hintergrund ein mann mit eimer und rechen in der hand .',
#   'a statue of an angle with a large disk and a man with a yellow coat and trashcan in the background .'),
#  ('ein frau verkauft backwaren an einem stand .',
#   'two young women examine the wares at a well-stocked outdoor bakery booth under a yellow umbrella .'),
#  ('eine frau sitzt auf einem baum und hält einen vogel in der hand',
#   'a blond woman in a white dress sits in a flowering tree while holding a white bird .'),
#  ('zwei mädchen unterstützen sich beim schlittschuhlaufen .',
#   'the two girls hold hands with one another while they skate on the ice .'),
#  ('2 kinder ligen auf einer schwaren couch und vier leuten stehen daneben',
#   'two tired children rest on couches at an art museum while the adults around them view the art .'),
#  ('zwei kinder spielen am strand mit einem stock im sonnenuntergang .',
#   'two children , one of which is holding a stick , are standing on the beach as the sun begins to set .'),
#  ('einen älteren herren beim zimmer streichen .',
#   'a man wearing white overalls and a baseball cap is holding a paintbrush .'),
#  ('einen älteren herren mit anzug , der auf einer parkbank ein nickerchen hält .',
#   'a man in a suit dozes on a park bench , with a sign for the subway in the background .'),
#  ('ein mann döst liegend an einen stein angelehnt .',
#   'a man of the street taking a nap resting his head on a rock. while'),
#  ('jemand knüpft verschiedene bunte tücher und stoffe .',
#   'someone wearing a large hat is sitting on colorful blankets working a loom with a pair of men &apos;s dress shoes in front of him .'),
#  ('ein mann saugt dem boden mit einem staubsauger',
#   'a bald man in an orange shirt and jeans is vacuuming an office carpet with a carry-along canister vacuum .'),
#  ('afrikanische männer arbeiten auf einem feld .',
#   'an african man wearing a maroon suit top is leaning next to a tall tied bundle of sticks , with bales of leaves in the background .'),
#  ('einen braunen hund der spazieren geht in der wiese .',
#   'a brown dog stands in a lush field with the stunning clouds and mountains behind it .'),
#  ('der asiatische mann sitzt in der bahn und schläft .',
#   'a young man in a suit and tie leans against a railing to take a nap on public transit .'),
#  ('eine frau bereitet einen waffelteig zu .',
#   'a woman in a white shirt and blue checker pants is cooking waffles in the kitchen .'),
#  ('2 männer schlafen auf einem tisch .',
#   'two people have their heads down on a table while a man in a brown jacket looks out the window at a group of bikes and motorcycles .'),
#  ('eine fahhradfahrerin liegt erschöpft aud dem boden und andere helfen ihr .',
#   'many people are crowding around a lady in a red shirt who is laying down hurt next to two bikes .'),
#  ('ein mann arbeitet auf einem gerüst .',
#   'a man in a white t-shirt and jeans standing on a scaffold outside a building .'),
#  ('eine bar mit köchen und kellner .',
#   'two chefs talk together behind a tiled restaurant calendar in a fancy restaurant .'),
#  ('eine frau grillt und kocht .',
#   'a woman prepares a plate of meat coming directly off of a grill while people talk in the background .'),
#  ('mann spielt blashorn',
#   'a man with a large horn sitting in front of an calvin klein steel , featuring a black man staring on .'),
#  ('vater und tochter beim spaziergang im park',
#   'there is a man in shorts and sandals and a woman in blue jean shorts and flip-flops out walking together .'),
#  ('zwei tänzer performen auf der straße .',
#   'the man is dancing with a doll wearing a red dress and heels .'),
#  ('ein kind das ein bonbon in der hand hält .',
#   'a little boy with a cream colored shirt holding a small piece of candy in a wrapper .'),
#  ('einen mann der kisten in einen container schmeißt .',
#   'a man &apos;s pants are falling down as he throws crates into a dumpster .'),
#  ('feuerwehrmann mit spritze in der stadt',
#   'an elderly firefighter in an orange suit is holding a fire hose with water coming out .'),
#  ('ein junger karateka trainiert in einer sporthalle .',
#   '2 boys in the foreground in a karate competition and coaches in background looking on with another coach sitting at table .'),
#  ('eine große gruppe menschen marschiert mit vielen luftballons .',
#   'a large group of people walks beneath an arc made of balloons in a grassy clearing .'),
#  ('einige leute stehen am strassenrand',
#   'this is a picture of a broadway rite aid pharmacy that has a bright neon sign and people are prepared to cross the street in front of it .'),
#  ('jemand beim kaffeetringen in einen straßenkaffee .',
#   'a woman blowing on a hot beverage while sitting at a table on the sidewalk .'),
#  ('ein mann spiel bowling .',
#   'a man wearing jeans swings back his arm in preparation to release the bowling ball down the lane .'),
#  ('eine frau schminkt ihr lid mit einem wattestäbchen ab .',
#   'a young woman with red highlights in her hair is applying eyeshadow with a q-tip in front of a mirror .'),
#  ('ein hund rennt über eine wiese .',
#   'a black dog is running across a low cut field nearby an area of trees .'),
#  ('ein mann liest vor einer buchhandlung ein buch .',
#   'a man is reading a book while sitting on a bench outside of a bookstore .'),
#  ('ein mann der eine pfanne hält .',
#   'a young man in a red t-shirt is cooking with a skillet .'),
#  ('ein mann gibt einem anderen einen kuss auf die wange .',
#   'a man wearing a tuxedo shirt , vest , and bowtie is kissing another man wearing the same thing on the cheek .'),
#  ('eine gruppe junger leute mit blauen hosen und weißen jacken läuft am pflaster entgegen .',
#   'a group of students are dressed in white and blue while marching down the street .'),
#  ('frau mit kindern auf einem balkon eines kirmisgeschäfts',
#   'a woman and two children walking through the upper levels of a carnival attraction .'),
#  ('3 straßenmusikanten vor werbeplakat',
#   'three street musicians wearing brown coats play the drums and trumpet in front of a store .'),
#  ('eine person spaziert mit einem angeleinten schwein auf einem feldweg .',
#   'a man , wearing a red sash and white shirt , walks a pig with a long piece of rope'),
#  ('drei frauen stehen auf einem platz , zwei davon haben grüne stiefel an .',
#   'two young ladies in green boots are walking through an urban area while an older lady wearing black shoes follows them .'),
#  ('einen straßenmarkt wo eingekauft wird .',
#   'various vendors selling produce in an eastern outdoor market .'),
#  ('eine frau mit sonnenbrille schaut aus dem fenster eines cafes .',
#   'a woman wearing sunglasses sits inside of a building with several other people looking outside .'),
#  ('ein mann gestikuliert .',
#   'two african american men wearing vests , as one african american man wearing a blue shirt with an emblem direct people or machinery .'),
#  ('ein kleines mädchen schaukelt .',
#   'a young baby girl wearing a white outfit swinging in a baby swing'),
#  ('ein kleines kindsteht am strand mit den füssen im wasser',
#   'a woman in a red jacket stands on the beach facing the water as it covers her feet .'),
#  ('kinder spielen am strand .',
#   'a young girl and boy in swimsuits happily play in the sand on a beach .'),
#  ('eine frau nimmt ein schaumbad .',
#   'a smiling female with nice teeth taking a bubble bath , two earrings in her right ear and a short haircut .'),
#  ('einen jungen der mit einem plastikschiff im wasser spielt .',
#   'a young dark-haired boy wearing black and white checkered clothing is playing with a yellow toy boat in the shallow waters of a beach .'),
#  ('einen mann der breakdance macht .',
#   'a young male wearing a red shirt and black pants is performing a dance technique in a terminal station for travelers .'),
#  ('ein pärchen macht wassersport .',
#   'a tanned woman and man in swimwear paired together in a colorful kayak with river water splashing all around them .'),
#  ('eine frau macht einen handstand .',
#   'a female wearing a black shirt and dark blue pants is practicing gymnastics on a beam , performing a handstnad split that exposes her bellybutton .'),
#  ('ein mann macht eine schüssel sauber',
#   'a man in an orange shirt smears something in a large white bowl .'),
#  ('2 kinder mit helm spielen und eine frau steht daneben',
#   'two kids with helmets playing with nerf swords while one looks on drinking from a plastic cup .'),
#  ('eine frau schaukelt ein kleines mädchen auf der schaukel',
#   'a child in a yellow plastic safety swing is laughing as a dark-haired woman in pink and coral pants stands behind her .'),
#  ('zwei kinder die am spielen sind',
#   'two boys wearing matching blue polo shirts strike a goofy pose .'),
#  ('viele menschen warten auf dem zug',
#   'a crowd of people are standing on a train platform are unconcerned as a train passes them by .'),
#  ('ein mädchen mit einem stock in der hand läuft einen weg entlang .',
#   'a little blond girl holding a stick walks down a cement path in pink capris .'),
#  ('ein mann mit einem kleinen karren dem etwas auf die strasse gefallen ist',
#   'one man in a brown coat steadying a cart with two boxes of fruit while trying to retrieve a pear that fell on the bumpy pavement made of brick .'),
#  ('eine vietnamesische verkäuferin steht in ihrem verkaufsstand .',
#   'a female street vendor is standing inside her kiosks which appears to sell a variety of foreign and handmade snacks .'),
#  ('die männer stehen im zimmer und diskutieren .',
#   'a man in a pair of jeans and a yellow shirt with a paper hanging out of his back pocket enjoys a laugh with a man in jeans and a white shirt at what looks like a meeting coming to an end .'),
#  ('eine frau hält eine geschälte ananas in der hand .',
#   'native woman in blue dress prepares pineapple and other fruits .'),
#  ('drei dudelsackspieler , ein trommler und ein läufer .',
#   'a man running in a marathon runs past 3 bagpipe players , and a drummer , all wearing a uniform'),
#  ('ein mann steht vor einem barbequegrill und schaut hinein .',
#   'man in white tea shirt , denim paints and blue apron attends to barbecue on a truck trailer .'),
#  ('ein klienes mädchen mit einem teddy im arm rennt einen weg entlang .',
#   'a young girl wearing a blue dress runs down a gravel road with a teddy bear .'),
#  ('ein mann in boot beim angeln',
#   'man in boat wearing athletic shorts , a backwards baseball cap and sunglasses unhooks a fish he has caught while fishing .'),
#  ('ein mann sitzt auf einer couch .',
#   'a man in a green tank top wearing a rabbits foot around his neck sits on a small sofa with the window open revealing a man in a white shirt on the other side of the window .'),
#  ('2 leute backen in einer gossküche gebäck',
#   'a man wearing a cap and green shirt with his back to the camera in an industrial kitchen .'),
#  ('zwei junge damen überqueren eine straße .',
#   'two women in shorts and shirts are walking holding their purses on their right shoulder .'),
#  ('ein mann wandert klippen entlang .',
#   'a man with a black and blue backpack hikes down a rock face .'),
#  ('eine turnerin springt über einen bock .',
#   'this picture is of a young girl practicing gymnastics in a gym .'),
#  ('zwei hunde spielen im schnee .',
#   'one dog climbing on the back of another dog in the snow .'),
#  ('ein mann steht auf einem felsen und streckt ein bein nach vorn .',
#   'a man dressed in dark clothing and a black hat is precariously stepping off the edge of a small cliff formation with the largest part of the formation and the desert landscape behind him .'),
#  ('drei frauen mit kopfschleier beim betrachten von fotos .',
#   'three females wearing headscarves standing together'),
#  ('ein junge sitzt auf einer mauer mit fahrrad .',
#   'a foreign store and hotel with streets that look run down with a kid in a bicycle sitting .'),
#  ('zwei fahrradfahrer fahren im sonnenuntergang .',
#   '2 people one wearing a blue shirt the other orange taking a bike ride in the country with a beautiful orange sunset behind them .'),
#  ('ein mann mit einer gelben kamera fotografiert .',
#   'a man wearing a get a job t-shirt takes a picture of the camera holder with a bright yellow camera while also holding a photo in his left hand .'),
#  ('ein gefülltes stadion bei einem baseballspiel .',
#   'the players of the baseball team are standing on the field , with many people watching from the stands .'),
#  ('ein mann und ein kleiner junge laufen auf einem pfad',
#   'a young boy in a red shirt and his older friend are heading down a heavily-wooded trail .'),
#  ('ein junge hilft einem anderen einen laternenpfahl hochzuklettern .',
#   'one small boy climbing a pole with the help of another boy on the ground'),
#  ('ein mann im anzug steht auf der strasse',
#   'a man with a white shirt and tie is standing on a sidewalk between cement barriers .'),
#  ('ein kind auf einem klettergerüst am spielplatz .',
#   'an individual is climbing on an objects while the bottom of his shoes can be seen .'),
#  ('viele kinder die nebeneinander stehen und die amerikanische hymne singen .',
#   'young children practicing karate are organized in a gymnasium facing the american flag , being watched by adults in black and yellow karate outfits .'),
#  ('2 asiaten üben eine kampfsport vor puplikum aus',
#   'in a martial arts demonstration a man with two swords faces a woman with a chinese spear .'),
#  ('zwei boxkämpfer trainieren gemeinsam .',
#   'two boxers wearing protective gear are fighting , with onlookers watching .'),
#  ...]

# %%
#using field for structuring all the given datas into lower case, star of sentences and end of sentences

english = Field(tokenize=tok_english, lower=True, init_token="<sos>", eos_token="<eos>")
german = Field(tokenize=tok_german, lower=True, init_token="<sos>", eos_token="<eos>")

# %%
fields=[('german',german),('english',english)]

# %%
# Create train datasets
train_examples = [torchtext.data.Example.fromlist([pair[0], pair[1]], fields) for pair in train_data]
train_dataset = torchtext.data.Dataset(train_examples, fields)

# %%
#checking our datasets
eg= train_dataset[0]
print(f"english:{eg.english}, german:{eg.german}")
# Out:
# english:['two', 'young', 'guys', 'with', 'shaggy', 'hair', 'look', 'at', 'their', 'hands', 'while', 'hanging', 'out', 'in', 'the', 'yard', '.'], german:['zwei', 'männer', 'betrachten', 'etwas', 'im', 'garten']

# %%
#Building vocab for our training datas

english.build_vocab(train_dataset, max_size= 10000, min_freq=2)
german.build_vocab(train_dataset, max_size= 10000, min_freq=2)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
#creating an encoder class

class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, embedding_size, num_layers, d):
        super(Encoder, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size= embedding_size
        self.num_layers = num_layers
        self.dropout = nn.Dropout(d)
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=d)

    def forward(self,x):
        embedding = self.dropout(self.embedding(x))
        output,(hidden,cell) = self.rnn(embedding)
        return hidden,cell

# %%
# creating a decoder class

class Decoder(nn.Module):
    def __init__(self, input_size, hidden_size, embedding_size, output_size, num_layers,d):
        super(Decoder, self).__init__()

        self.hidden_size=hidden_size
        self.num_layers=num_layers
        self.dropout = nn.Dropout(d)
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size, hidden_size, num_layers, dropout=d)
        self.fc = nn.Linear(hidden_size, output_size)


    def forward(self, x, hidden, cell):
        # x shape: (N) where N is for batch size, we want it to be (1, N), seq_length
        # is 1 here because we are sending in a single word and not a sentence
        x = x.unsqueeze(0)

        embedding = self.dropout(self.embedding(x))
        # embedding shape: (1, N, embedding_size)

        outputs, (hidden, cell) = self.rnn(embedding, (hidden, cell))
        # outputs shape: (1, N, hidden_size)

        predictions = self.fc(outputs)

        # predictions shape: (1, N, length_target_vocabulary) to send it to
        # loss function we want it to be (N, length_target_vocabulary) so we're
        # just gonna remove the first dim
        predictions = predictions.squeeze(0)

        return predictions, hidden, cell

# %%
#Now combining our encoder and decoder into seq2seq module

class Seq2seq(nn.Module):
    def __init__(self, encoder, decoder):
        super(Seq2seq, self).__init__()

        self.encoder=encoder
        self.decoder=decoder

    def forward(self, source, target, teacher_force_ratio=0.5):
        batch_size = source.shape[1]
        target_len = target.shape[0]
        target_vocab_size = len(english.vocab)

        outputs = torch.zeros(target_len, batch_size, target_vocab_size).to(device)

        #passing source through encoder
        hidden, cell = self.encoder(source)

     #After this grab the first <sos> of the target
        x= target[0]

        for t in range(1, target_len):
            #Now feed target and the data from hidden and cell  into the decoder
            output, hidden, cell = self.decoder(x,hidden, cell)

            #storing the predicted values
            outputs[t]= output

            #now selecting the best guess among the result
            best_result = output.argmax(1)

            #using the teacher learning ratio for the best and smooth predictions
            x = target[t] if random.random() < teacher_force_ratio else best_result

        return outputs

# %%
# Model hyperparameters
load_model = False
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_size_encoder = len(german.vocab)
input_size_decoder = len(english.vocab)
output_size = len(english.vocab)
encoder_embedding_size = 300
decoder_embedding_size = 300
hidden_size = 1024  # Needs to be the same for both RNN's
num_layers = 2
enc_dropout = 0.5
dec_dropout = 0.5

# %%
encoder_net = Encoder(input_size_encoder,hidden_size, encoder_embedding_size, num_layers,enc_dropout).to(device)
decoder_net = Decoder(input_size_decoder,hidden_size, decoder_embedding_size,output_size, num_layers,enc_dropout).to(device)
model = Seq2seq(encoder_net, decoder_net).to(device)

# %%
print(encoder_net)
print("")
print(decoder_net)
print("")
print(model)
# Out:
# Encoder(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (embedding): Embedding(5714, 300)
#   (rnn): LSTM(300, 1024, num_layers=2, dropout=0.5)
# )
#
# Decoder(
#   (dropout): Dropout(p=0.5, inplace=False)
#   (embedding): Embedding(7294, 300)
#   (rnn): LSTM(300, 1024, num_layers=2, dropout=0.5)
#   (fc): Linear(in_features=1024, out_features=7294, bias=True)
# )
#
# Seq2seq(
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embedding): Embedding(5714, 300)
#     (rnn): LSTM(300, 1024, num_layers=2, dropout=0.5)
#   )
#   (decoder): Decoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embedding): Embedding(7294, 300)
#     (rnn): LSTM(300, 1024, num_layers=2, dropout=0.5)
#     (fc): Linear(in_features=1024, out_features=7294, bias=True)
#   )
# )

# %%
# Training hyperparameters
num_epochs = 20
learning_rate = 0.001
batch_size = 64

# %%
#creating our iterator for taining
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_dataset, train_dataset, train_dataset),
    batch_size=batch_size,
    sort_within_batch=True,
    sort_key=lambda x: len(x.english),
    device=device,
)

# %%
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
pad_idx = english.vocab.stoi["<pad>"]
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

# %%
writer= SummaryWriter()
step=0

# %%
from tqdm.notebook import tqdm

# %%
if load_model:
    load_checkpoint(torch.load("my_checkpoint.pth.tar"), model, optimizer)


sentence = "Ein dicker Mann stürzte die Klippe hinunter"
for epoch in tqdm(range(num_epochs)):
    print(f"[Epoch {epoch} / {num_epochs}]")

    if epoch%9==0:
      checkpoint = {"state_dict": model.state_dict(), "optimizer": optimizer.state_dict(),"epoch":epoch}
      print("===> saving model")
      torch.save(checkpoint,"/content/my_checkpoint.pth.tar")
    model.eval()

    translated_sentence = translate_sentence(
        model, sentence, german, english, device, max_length=50
    )

    print(f"Translated example sentence: \n {translated_sentence}")

    model.train()

    for batch_idx, batch in enumerate(train_iterator):
        # Get input and targets and get to cuda
        inp_data = batch.german.to(device)
        target = batch.english.to(device)

        # Forward prop
        output = model(inp_data, target)

        # Output is of shape (trg_len, batch_size, output_dim) but Cross Entropy Loss
        # doesn't take input in that form. For example if we have MNIST we want to have
        # output to be: (N, 10) and targets just (N). Here we can view it in a similar
        # way that we have output_words * batch_size that we want to send in into
        # our cost function, so we need to do some reshapin. While we're at it
        # Let's also remove the start token while we're at it
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
        loss = criterion(output, target)

        # Back prop
        loss.backward()

        # Clip to avoid exploding gradient issues, makes sure grads are
        # within a healthy range
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        # Gradient descent step
        optimizer.step()

        # Plot to tensorboard
        writer.add_scalar("Training loss", loss, global_step=step)
        step += 1



# score = bleu(train_dataset[1:100], model, german, english, device)
# print(f"Bleu score {score*100:.2f}")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# [Epoch 0 / 20]
# ===> saving model
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'stands', 'on', 'deep', 'snow', 'covered', 'the', 'ocean', '.', '<eos>']
# [Epoch 1 / 20]
# Translated example sentence:
#  ['a', 'man', 'is', 'a', 'black', 'hat', 'and', 'black', 'pants', 'is', 'standing', 'on', 'a', 'rock', '.', '<eos>']
# [Epoch 2 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'is', 'standing', 'on', 'a', 'rock', 'looking', 'at', 'the', 'ocean', '.', '<eos>']
# [Epoch 3 / 20]
# Translated example sentence:
#  ['a', 'climber', 'is', 'a', 'red', 'jacket', 'stands', 'on', 'deep', 'snow', '.', '<eos>']
# [Epoch 4 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'stands', 'on', 'deep', 'snow', '.', '<eos>']
# [Epoch 5 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'and', 'black', 'pants', 'is', 'on', 'a', 'rocky', '.', '<eos>']
# [Epoch 6 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'is', 'black', 'pants', 'is', 'standing', 'on', 'a', 'rocky', 'beach', '.', '<eos>']
# [Epoch 7 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'is', 'standing', 'a', 'waterfall', 'with', 'a', 'fishing', '.', '<eos>']
# [Epoch 8 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 't', '-', 'shirt', 'and', 'cargo', 'shorts', 'is', 'standing', 'on', 'a', 'dock', '.', '<eos>']
# [Epoch 9 / 20]
# ===> saving model
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'stands', 'on', 'a', 'rock', 'with', 'a', 'fishing', 'eaten', 'apple', '.', '<eos>']
# [Epoch 10 / 20]
# Translated example sentence:
#  ['a', 'man', 'is', 'a', 'black', 'jacket', 'is', 'on', 'a', 'rock', 'looking', 'down', 'a', 'mountain', '.', '<eos>']
# [Epoch 11 / 20]
# Translated example sentence:
#  ['an', 'older', 'man', 'is', 'a', 'a', 'climbing', 'up', 'a', 'rocky', 'mountainside', '.', '<eos>']
# [Epoch 12 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'stands', 'on', 'a', 'rock', 'looking', 'at', 'the', 'ocean', '.', '<eos>']
# [Epoch 13 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'red', 'jacket', 'stands', 'on', 'a', 'hiking', 'cliff', '.', '<eos>']
# [Epoch 14 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'red', 'jacket', 'stands', 'on', 'a', 'rock', 'looking', 'at', 'the', 'camera', '.', '<eos>']
# [Epoch 15 / 20]
# Translated example sentence:
#  ['a', 'man', 'is', 'leaning', 'against', 'a', 'mountain', 'while', 'overlooking', 'the', 'mountains', '.', '<eos>']
# [Epoch 16 / 20]
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'yellow', 'jacket', 'stands', 'on', 'a', 'small', 'rock', '.', '<eos>']
# [Epoch 17 / 20]
# Translated example sentence:
#  ['a', 'climber', 'is', 'a', 'blue', 'jacket', 'is', 'standing', 'down', 'a', 'snowy', 'hill', '.', '<eos>']
# [Epoch 18 / 20]
# ===> saving model
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'jacket', 'and', 'black', 'pants', 'is', 'on', 'a', 'a', '.', '<eos>']
# [Epoch 19 / 20]
# Translated example sentence:
#  ['a', 'man', 'is', 'leaning', 'on', 'a', 'white', 'face', 'over', 'a', 'body', 'of', 'water', '.', '<eos>']

# %% [markdown]
# LOADING THE MODEL FOR THE TESTIN PURPOSE AND CHECKING THE BLEU SCORE

# %%
torch.load("/content/my_checkpoint.pth.tar")
model.load_state_dict(checkpoint['state_dict'])
optimizer.load_state_dict(checkpoint['optimizer'])
start_epoch = checkpoint['epoch']

# %% [markdown]
# CODE TO LOAD THE CHECKPOINT AND CONTINUE TRAINING THE *MODEL*

# %%
# sentence = "Gordan Ramsay ist der Spitzenkoch auf der ganzen Welt"
for epoch in tqdm(range(start_epoch, 30)):
    print(f"[Epoch {epoch} / 30]")

    checkpoint = {"state_dict": model.state_dict(), "optimizer": optimizer.state_dict(),"epoch":epoch}
    print("===> saving model")
    torch.save(checkpoint,"/content/my_checkpoint.pth.tar")
    print(device)
    model.eval()

    translated_sentence = translate_sentence(
        model, sentence, german, english, device, max_length=50
    )

    print(f"Translated example sentence: \n {translated_sentence}")

    model.train()

    for batch_idx, batch in enumerate(train_iterator):
        # Get input and targets and get to cuda
        inp_data = batch.german.to(device)
        target = batch.english.to(device)

        # Forward prop
        output = model(inp_data, target)

        # Output is of shape (trg_len, batch_size, output_dim) but Cross Entropy Loss
        # doesn't take input in that form. For example if we have MNIST we want to have
        # output to be: (N, 10) and targets just (N). Here we can view it in a similar
        # way that we have output_words * batch_size that we want to send in into
        # our cost function, so we need to do some reshapin. While we're at it
        # Let's also remove the start token while we're at it
        output = output[1:].reshape(-1, output.shape[2])
        target = target[1:].reshape(-1)

        optimizer.zero_grad()
        loss = criterion(output, target)

        # Back prop
        loss.backward()

        # Clip to avoid exploding gradient issues, makes sure grads are
        # within a healthy range
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

        # Gradient descent step
        optimizer.step()

        # Plot to tensorboard
        writer.add_scalar("Training loss", loss, global_step=step)
        step += 1
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# [Epoch 18 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['an', 'emergency', 'man', 'in', 'a', 'ivory', 'colored', 'coat', 'is', 'leaning', 'against', 'a', '<unk>', 'and', 'cleaning', 'a', 'drink', '.', '<eos>']
# [Epoch 19 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['an', 'emergency', 'crew', 'caring', 'for', '<unk>', 'out', 'of', 'the', 'podium', '.', '<eos>']
# [Epoch 20 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'shirt', 'places', 'a', 'piece', 'of', 'equipment', '.', '<eos>']
# [Epoch 21 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'emergency', 'worker', 'is', 'a', 'moment', 'in', 'wipe', 'his', 'face', '.', '<eos>']
# [Epoch 22 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'shirt', 'and', 'black', 'hat', 'is', 'holding', 'up', 'a', 'piece', 'of', 'paper', '.', '<eos>']
# [Epoch 23 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['an', 'emergency', 'crew', 'caring', 'for', 'a', 'next', 'to', 'a', 'small', 'red', '.', '<eos>']
# [Epoch 24 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['an', 'emergency', 'crew', 'caring', 'in', 'front', 'of', 'a', '<unk>', '<unk>', '.', '<eos>']
# [Epoch 25 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'emergency', 'worker', 'uses', 'a', 'moment', 'to', 'wipe', 'a', 'liquid', 'together', '.', '<eos>']
# [Epoch 26 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['an', 'emergency', 'crew', 'caring', 'in', 'a', '<unk>', 'factory', '.', '<eos>']
# [Epoch 27 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'emergency', 'worker', 'is', 'performing', 'a', 'piece', 'wipe', 'a', 'piece', 'of', '<eos>']
# [Epoch 28 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['a', 'man', 'in', 'a', 'black', 'suit', 'and', 'a', 'a', 'a', 'a', 'cleaning', 'a', 'elephant', '.', '<eos>']
# [Epoch 29 / 30]
# ===> saving model
# cuda
# Translated example sentence:
#  ['protesters', 'emergency', 'lab', 'and', 'playing', 'a', 'a', 'car', '.', '<eos>']

# %% [markdown]
# TESTING OUR MODEL WORKING

# %%
torch.load("/content/my_checkpoint.pth.tar")
test_sentence = "sie ist grausam"
model.eval()
translated_sentence = translate_sentence(
    model, test_sentence, german, english, device, max_length=50
)

print(f"Translated example sentence: \n {translated_sentence}")
# Out:
# Translated example sentence:
#  ['near', 'a', '<unk>', 'wave', '.', '<eos>']

# %% [markdown]
# BLEU SCORE

# %%
targets = []
outputs = []
for  example in tqdm(train_dataset.examples[1:100]):

      src = example.german
      trg = example.english
      # print(src)
      prediction = translate_sentence(model, src, german, english, device)
      # print(prediction[:-1])
      targets.append([trg])
      outputs.append(prediction)
print(bleu_score(outputs, targets))
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# 0.0586862635484308
